# %% [markdown]
# # Intro to learning Python!

# %% [markdown]
# I'm in the early stages of learning but I think it will be useful to store what I do here for future reference.
# Importantly, I'm also linking this to GitHub so I can come back to it at any time!

# %%
print("Hello World")
# Out:
# Hello World
